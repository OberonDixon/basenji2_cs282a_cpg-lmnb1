# %%
from __future__ import print_function
from optparse import OptionParser
import json
import os
import pdb
import sys

import h5py
import numpy as np
import pandas as pd
from scipy.stats import pearsonr, spearmanr
from sklearn.linear_model import Ridge, ElasticNet
from sklearn.metrics import explained_variance_score
from sklearn.preprocessing import scale
import tensorflow as tf

from basenji.basenji import dataset #must change from basenji import dataset to from basenji.basenji import dataset
from basenji.basenji import seqnn #must change import statements in each of these files too
from basenji.basenji import trainer
from qnorm import quantile_normalize #must pip install qnorm

# For one hot encoding
import pysam
from basenji.dna_io import dna_1hot
from tqdm import tqdm
# Out:
# 2023-11-21 10:31:06.671269: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-21 10:31:06.718560: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-21 10:31:07.334701: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Load files
params_file = 'params_human.json'
model_file = 'model_human.h5'
targets_file = 'targets_human.txt'
hg38_genome_path = '/home/sbrener/repos/hg38.fa'
sequences_bed_path = '/home/sbrener/repos/sequences.bed'
dataset_filepath = '/media/longterm_hdd/sbrener/basenji_embeddings/embeddings.h5'

# One hot encode the sequences & save to file!
hg38_fasta = pysam.FastaFile(hg38_genome_path)
seqbedlen = 38171

# Load params
with open(params_file) as params_open:
    params = json.load(params_open)
params_model = params['model']
params_train = params['train']

#Load model
seqnn_model = seqnn.SeqNN(params_model)
seqnn_model.restore(model_file)
seqnn_model.build_embed(-1) # this gets embeddings from one layer before the final layer. To get the final layer embeddings, don't run this line.

# One hot encode the sequences, obtain embeddings, and save to file
with open(sequences_bed_path,'r') as bed_file, h5py.File(dataset_filepath,'w') as embed_file:
    embed_file.create_dataset(
        'embeddings',
        shape=(seqbedlen,896,1536),
        chunks=(1,896,1536),
        compression='gzip',
        compression_opts=9,
        dtype='float16'
    )    
    progress_bar = tqdm(enumerate(bed_file), total=seqbedlen)
    for index,bed_line in progress_bar:
        location_fields = bed_line.split('\t')
        chrom = str(location_fields[0])
        start = int(location_fields[1])
        end = int(location_fields[2])
        seq_type = location_fields[3].strip()
        progress_bar.set_description(f"Processing {seq_type} sequences")  # Update the progress bar description
        seq = hg38_fasta.fetch(chrom,start,end)
        onehot_seq = dna_1hot(seq)
        embeddings = np.array(seqnn_model.predict(onehot_seq[None,:,:],verbose=0))
        embed_file['embeddings'][index,:,:] = embeddings
# Out:
# Model: "model_15"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  sequence (InputLayer)       [(None, 131072, 4)]          0         []
#
#  tf.nn.gelu_217 (TFOpLambda  (None, 131072, 4)            0         ['sequence[0][0]']
#  )
#
#  conv1d_210 (Conv1D)         (None, 131072, 288)          17280     ['tf.nn.gelu_217[0][0]']
#
#  batch_normalization_210 (B  (None, 131072, 288)          1152      ['conv1d_210[0][0]']
#  atchNormalization)
#
#  max_pooling1d_49 (MaxPooli  (None, 65536, 288)           0         ['batch_normalization_210[0][0
#  ng1D)                                                              ]']
#
#  tf.nn.gelu_218 (TFOpLambda  (None, 65536, 288)           0         ['max_pooling1d_49[0][0]']
#  )
#
#  conv1d_211 (Conv1D)         (None, 65536, 339)           488160    ['tf.nn.gelu_218[0][0]']
#
#  batch_normalization_211 (B  (None, 65536, 339)           1356      ['conv1d_211[0][0]']
#  atchNormalization)
#
#  max_pooling1d_50 (MaxPooli  (None, 32768, 339)           0         ['batch_normalization_211[0][0
#  ng1D)                                                              ]']
#
#  tf.nn.gelu_219 (TFOpLambda  (None, 32768, 339)           0         ['max_pooling1d_50[0][0]']
#  )
#
#  conv1d_212 (Conv1D)         (None, 32768, 399)           676305    ['tf.nn.gelu_219[0][0]']
#
#  batch_normalization_212 (B  (None, 32768, 399)           1596      ['conv1d_212[0][0]']
#  atchNormalization)
#
#  max_pooling1d_51 (MaxPooli  (None, 16384, 399)           0         ['batch_normalization_212[0][0
#  ng1D)                                                              ]']
#
#  tf.nn.gelu_220 (TFOpLambda  (None, 16384, 399)           0         ['max_pooling1d_51[0][0]']
#  )
#
#  conv1d_213 (Conv1D)         (None, 16384, 470)           937650    ['tf.nn.gelu_220[0][0]']
#
#  batch_normalization_213 (B  (None, 16384, 470)           1880      ['conv1d_213[0][0]']
#  atchNormalization)
#
#  max_pooling1d_52 (MaxPooli  (None, 8192, 470)            0         ['batch_normalization_213[0][0
#  ng1D)                                                              ]']
#
#  tf.nn.gelu_221 (TFOpLambda  (None, 8192, 470)            0         ['max_pooling1d_52[0][0]']
#  )
#
#  conv1d_214 (Conv1D)         (None, 8192, 554)            1301900   ['tf.nn.gelu_221[0][0]']
#
#  batch_normalization_214 (B  (None, 8192, 554)            2216      ['conv1d_214[0][0]']
#  atchNormalization)
#
#  max_pooling1d_53 (MaxPooli  (None, 4096, 554)            0         ['batch_normalization_214[0][0
#  ng1D)                                                              ]']
#
#  tf.nn.gelu_222 (TFOpLambda  (None, 4096, 554)            0         ['max_pooling1d_53[0][0]']
#  )
#
#  conv1d_215 (Conv1D)         (None, 4096, 652)            1806040   ['tf.nn.gelu_222[0][0]']
#
#  batch_normalization_215 (B  (None, 4096, 652)            2608      ['conv1d_215[0][0]']
#  atchNormalization)
#
#  max_pooling1d_54 (MaxPooli  (None, 2048, 652)            0         ['batch_normalization_215[0][0
#  ng1D)                                                              ]']
#
#  tf.nn.gelu_223 (TFOpLambda  (None, 2048, 652)            0         ['max_pooling1d_54[0][0]']
#  )
#
#  conv1d_216 (Conv1D)         (None, 2048, 768)            2503680   ['tf.nn.gelu_223[0][0]']
#
#  batch_normalization_216 (B  (None, 2048, 768)            3072      ['conv1d_216[0][0]']
#  atchNormalization)
#
#  max_pooling1d_55 (MaxPooli  (None, 1024, 768)            0         ['batch_normalization_216[0][0
#  ng1D)                                                              ]']
#
#  tf.nn.gelu_224 (TFOpLambda  (None, 1024, 768)            0         ['max_pooling1d_55[0][0]']
#  )
#
#  conv1d_217 (Conv1D)         (None, 1024, 384)            884736    ['tf.nn.gelu_224[0][0]']
#
#  batch_normalization_217 (B  (None, 1024, 384)            1536      ['conv1d_217[0][0]']
#  atchNormalization)
#
#  tf.nn.gelu_225 (TFOpLambda  (None, 1024, 384)            0         ['batch_normalization_217[0][0
#  )                                                                  ]']
#
#  conv1d_218 (Conv1D)         (None, 1024, 768)            294912    ['tf.nn.gelu_225[0][0]']
#
#  batch_normalization_218 (B  (None, 1024, 768)            3072      ['conv1d_218[0][0]']
#  atchNormalization)
#
#  dropout_84 (Dropout)        (None, 1024, 768)            0         ['batch_normalization_218[0][0
#                                                                     ]']
#
#  add_77 (Add)                (None, 1024, 768)            0         ['max_pooling1d_55[0][0]',
#                                                                      'dropout_84[0][0]']
#
#  tf.nn.gelu_226 (TFOpLambda  (None, 1024, 768)            0         ['add_77[0][0]']
#  )
#
#  conv1d_219 (Conv1D)         (None, 1024, 384)            884736    ['tf.nn.gelu_226[0][0]']
#
#  batch_normalization_219 (B  (None, 1024, 384)            1536      ['conv1d_219[0][0]']
#  atchNormalization)
#
#  tf.nn.gelu_227 (TFOpLambda  (None, 1024, 384)            0         ['batch_normalization_219[0][0
#  )                                                                  ]']
#
#  conv1d_220 (Conv1D)         (None, 1024, 768)            294912    ['tf.nn.gelu_227[0][0]']
#
#  batch_normalization_220 (B  (None, 1024, 768)            3072      ['conv1d_220[0][0]']
#  atchNormalization)
#
#  dropout_85 (Dropout)        (None, 1024, 768)            0         ['batch_normalization_220[0][0
#                                                                     ]']
#
#  add_78 (Add)                (None, 1024, 768)            0         ['add_77[0][0]',
#                                                                      'dropout_85[0][0]']
#
#  tf.nn.gelu_228 (TFOpLambda  (None, 1024, 768)            0         ['add_78[0][0]']
#  )
#
#  conv1d_221 (Conv1D)         (None, 1024, 384)            884736    ['tf.nn.gelu_228[0][0]']
#
#  batch_normalization_221 (B  (None, 1024, 384)            1536      ['conv1d_221[0][0]']
#  atchNormalization)
#
#  tf.nn.gelu_229 (TFOpLambda  (None, 1024, 384)            0         ['batch_normalization_221[0][0
#  )                                                                  ]']
#
#  conv1d_222 (Conv1D)         (None, 1024, 768)            294912    ['tf.nn.gelu_229[0][0]']
#
#  batch_normalization_222 (B  (None, 1024, 768)            3072      ['conv1d_222[0][0]']
#  atchNormalization)
#
#  dropout_86 (Dropout)        (None, 1024, 768)            0         ['batch_normalization_222[0][0
#                                                                     ]']
#
#  add_79 (Add)                (None, 1024, 768)            0         ['add_78[0][0]',
#                                                                      'dropout_86[0][0]']
#
#  tf.nn.gelu_230 (TFOpLambda  (None, 1024, 768)            0         ['add_79[0][0]']
#  )
#
#  conv1d_223 (Conv1D)         (None, 1024, 384)            884736    ['tf.nn.gelu_230[0][0]']
#
#  batch_normalization_223 (B  (None, 1024, 384)            1536      ['conv1d_223[0][0]']
#  atchNormalization)
#
#  tf.nn.gelu_231 (TFOpLambda  (None, 1024, 384)            0         ['batch_normalization_223[0][0
#  )                                                                  ]']
#
#  conv1d_224 (Conv1D)         (None, 1024, 768)            294912    ['tf.nn.gelu_231[0][0]']
#
#  batch_normalization_224 (B  (None, 1024, 768)            3072      ['conv1d_224[0][0]']
#  atchNormalization)
#
#  dropout_87 (Dropout)        (None, 1024, 768)            0         ['batch_normalization_224[0][0
#                                                                     ]']
#
#  add_80 (Add)                (None, 1024, 768)            0         ['add_79[0][0]',
#                                                                      'dropout_87[0][0]']
#
#  tf.nn.gelu_232 (TFOpLambda  (None, 1024, 768)            0         ['add_80[0][0]']
#  )
#
#  conv1d_225 (Conv1D)         (None, 1024, 384)            884736    ['tf.nn.gelu_232[0][0]']
#
#  batch_normalization_225 (B  (None, 1024, 384)            1536      ['conv1d_225[0][0]']
#  atchNormalization)
#
#  tf.nn.gelu_233 (TFOpLambda  (None, 1024, 384)            0         ['batch_normalization_225[0][0
#  )                                                                  ]']
#
#  conv1d_226 (Conv1D)         (None, 1024, 768)            294912    ['tf.nn.gelu_233[0][0]']
#
#  batch_normalization_226 (B  (None, 1024, 768)            3072      ['conv1d_226[0][0]']
#  atchNormalization)
#
#  dropout_88 (Dropout)        (None, 1024, 768)            0         ['batch_normalization_226[0][0
#                                                                     ]']
#
#  add_81 (Add)                (None, 1024, 768)            0         ['add_80[0][0]',
#                                                                      'dropout_88[0][0]']
#
#  tf.nn.gelu_234 (TFOpLambda  (None, 1024, 768)            0         ['add_81[0][0]']
#  )
#
#  conv1d_227 (Conv1D)         (None, 1024, 384)            884736    ['tf.nn.gelu_234[0][0]']
#
#  batch_normalization_227 (B  (None, 1024, 384)            1536      ['conv1d_227[0][0]']
#  atchNormalization)
#
#  tf.nn.gelu_235 (TFOpLambda  (None, 1024, 384)            0         ['batch_normalization_227[0][0
#  )                                                                  ]']
#
#  conv1d_228 (Conv1D)         (None, 1024, 768)            294912    ['tf.nn.gelu_235[0][0]']
#
#  batch_normalization_228 (B  (None, 1024, 768)            3072      ['conv1d_228[0][0]']
#  atchNormalization)
#
#  dropout_89 (Dropout)        (None, 1024, 768)            0         ['batch_normalization_228[0][0
#                                                                     ]']
#
#  add_82 (Add)                (None, 1024, 768)            0         ['add_81[0][0]',
#                                                                      'dropout_89[0][0]']
#
#  tf.nn.gelu_236 (TFOpLambda  (None, 1024, 768)            0         ['add_82[0][0]']
#  )
#
#  conv1d_229 (Conv1D)         (None, 1024, 384)            884736    ['tf.nn.gelu_236[0][0]']
#
#  batch_normalization_229 (B  (None, 1024, 384)            1536      ['conv1d_229[0][0]']
#  atchNormalization)
#
#  tf.nn.gelu_237 (TFOpLambda  (None, 1024, 384)            0         ['batch_normalization_229[0][0
#  )                                                                  ]']
#
#  conv1d_230 (Conv1D)         (None, 1024, 768)            294912    ['tf.nn.gelu_237[0][0]']
#
#  batch_normalization_230 (B  (None, 1024, 768)            3072      ['conv1d_230[0][0]']
#  atchNormalization)
#
#  dropout_90 (Dropout)        (None, 1024, 768)            0         ['batch_normalization_230[0][0
#                                                                     ]']
#
#  add_83 (Add)                (None, 1024, 768)            0         ['add_82[0][0]',
#                                                                      'dropout_90[0][0]']
#
#  tf.nn.gelu_238 (TFOpLambda  (None, 1024, 768)            0         ['add_83[0][0]']
#  )
#
#  conv1d_231 (Conv1D)         (None, 1024, 384)            884736    ['tf.nn.gelu_238[0][0]']
#
#  batch_normalization_231 (B  (None, 1024, 384)            1536      ['conv1d_231[0][0]']
#  atchNormalization)
#
#  tf.nn.gelu_239 (TFOpLambda  (None, 1024, 384)            0         ['batch_normalization_231[0][0
#  )                                                                  ]']
#
#  conv1d_232 (Conv1D)         (None, 1024, 768)            294912    ['tf.nn.gelu_239[0][0]']
#
#  batch_normalization_232 (B  (None, 1024, 768)            3072      ['conv1d_232[0][0]']
#  atchNormalization)
#
#  dropout_91 (Dropout)        (None, 1024, 768)            0         ['batch_normalization_232[0][0
#                                                                     ]']
#
#  add_84 (Add)                (None, 1024, 768)            0         ['add_83[0][0]',
#                                                                      'dropout_91[0][0]']
#
#  tf.nn.gelu_240 (TFOpLambda  (None, 1024, 768)            0         ['add_84[0][0]']
#  )
#
#  conv1d_233 (Conv1D)         (None, 1024, 384)            884736    ['tf.nn.gelu_240[0][0]']
#
#  batch_normalization_233 (B  (None, 1024, 384)            1536      ['conv1d_233[0][0]']
#  atchNormalization)
#
#  tf.nn.gelu_241 (TFOpLambda  (None, 1024, 384)            0         ['batch_normalization_233[0][0
#  )                                                                  ]']
#
#  conv1d_234 (Conv1D)         (None, 1024, 768)            294912    ['tf.nn.gelu_241[0][0]']
#
#  batch_normalization_234 (B  (None, 1024, 768)            3072      ['conv1d_234[0][0]']
#  atchNormalization)
#
#  dropout_92 (Dropout)        (None, 1024, 768)            0         ['batch_normalization_234[0][0
#                                                                     ]']
#
#  add_85 (Add)                (None, 1024, 768)            0         ['add_84[0][0]',
#                                                                      'dropout_92[0][0]']
#
#  tf.nn.gelu_242 (TFOpLambda  (None, 1024, 768)            0         ['add_85[0][0]']
#  )
#
#  conv1d_235 (Conv1D)         (None, 1024, 384)            884736    ['tf.nn.gelu_242[0][0]']
#
#  batch_normalization_235 (B  (None, 1024, 384)            1536      ['conv1d_235[0][0]']
#  atchNormalization)
#
#  tf.nn.gelu_243 (TFOpLambda  (None, 1024, 384)            0         ['batch_normalization_235[0][0
#  )                                                                  ]']
#
#  conv1d_236 (Conv1D)         (None, 1024, 768)            294912    ['tf.nn.gelu_243[0][0]']
#
#  batch_normalization_236 (B  (None, 1024, 768)            3072      ['conv1d_236[0][0]']
#  atchNormalization)
#
#  dropout_93 (Dropout)        (None, 1024, 768)            0         ['batch_normalization_236[0][0
#                                                                     ]']
#
#  add_86 (Add)                (None, 1024, 768)            0         ['add_85[0][0]',
#                                                                      'dropout_93[0][0]']
#
#  tf.nn.gelu_244 (TFOpLambda  (None, 1024, 768)            0         ['add_86[0][0]']
#  )
#
#  conv1d_237 (Conv1D)         (None, 1024, 384)            884736    ['tf.nn.gelu_244[0][0]']
#
#  batch_normalization_237 (B  (None, 1024, 384)            1536      ['conv1d_237[0][0]']
#  atchNormalization)
#
#  tf.nn.gelu_245 (TFOpLambda  (None, 1024, 384)            0         ['batch_normalization_237[0][0
#  )                                                                  ]']
#
#  conv1d_238 (Conv1D)         (None, 1024, 768)            294912    ['tf.nn.gelu_245[0][0]']
#
#  batch_normalization_238 (B  (None, 1024, 768)            3072      ['conv1d_238[0][0]']
#  atchNormalization)
#
#  dropout_94 (Dropout)        (None, 1024, 768)            0         ['batch_normalization_238[0][0
#                                                                     ]']
#
#  add_87 (Add)                (None, 1024, 768)            0         ['add_86[0][0]',
#                                                                      'dropout_94[0][0]']
#
#  cropping1d_7 (Cropping1D)   (None, 896, 768)             0         ['add_87[0][0]']
#
#  tf.nn.gelu_246 (TFOpLambda  (None, 896, 768)             0         ['cropping1d_7[0][0]']
#  )
#
#  conv1d_239 (Conv1D)         (None, 896, 1536)            1179648   ['tf.nn.gelu_246[0][0]']
#
#  batch_normalization_239 (B  (None, 896, 1536)            6144      ['conv1d_239[0][0]']
#  atchNormalization)
#
#  dropout_95 (Dropout)        (None, 896, 1536)            0         ['batch_normalization_239[0][0
#                                                                     ]']
#
#  tf.nn.gelu_247 (TFOpLambda  (None, 896, 1536)            0         ['dropout_95[0][0]']
#  )
#
#  dense_7 (Dense)             (None, 896, 5313)            8166081   ['tf.nn.gelu_247[0][0]']
#
# ==================================================================================================
# Total params: 30123584 (114.91 MB)
# Trainable params: 30088228 (114.78 MB)
# Non-trainable params: 35356 (138.11 KB)
# __________________________________________________________________________________________________
# None
# model_strides [128]
# target_lengths [896]
# target_crops [64]
# Processing test sequences: 100%|██████████| 38171/38171 [6:34:08<00:00,  1.61it/s]
